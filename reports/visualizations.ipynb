# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import os
import pathlib

# %%
#replace with path that will be created from preprocessing last line
df=pd.read_csv('C:/Users/musom/Desktop/final_scam_detection/data/bongo_scam_cleaned.csv')

# %%
#combine messages
all_text="".join(df['Sms'])

word_cloud=WordCloud(width=700,height=500).generate(all_text)

plt.figure(figsize=(10, 5))
plt.imshow(word_cloud, interpolation="bilinear")
plt.title("Word Cloud")
plt.show()

# %%
word_freq = Counter(all_text.split())
#count each
top_words = word_freq.most_common(10)
print(top_words)
# Out:
# [('namba', 447), ('jina', 414), ('hii', 333), ('pesa', 256), ('yako', 138), ('hela', 124), ('ela', 109), ('nitumie', 107), ('iyo', 106), ('need', 106)]

# %%
plt.figure(figsize=(10, 5))
plt.bar(*zip(*top_words))
plt.xlabel("word")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# Linguistic patterns:
#
# 1. The presence of 'hela', 'ela' and 'pesa' as some of the top words show that most scam sms involve texts requesting for money
# 2. Terms like "need" also show there is often a sense of urgency tied to this messages.
# 3. Lastly, there is often misspelling and/or broken kiswahili, seen from words like 'ela' and 'iyo'
